# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
ytt_api.fetch("MiVMEICbWsU", languages=['bgn','bg', 'en'])
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='[музика]', start=0.23, duration=15.289), FetchedTranscriptSnippet(text='Здравейте, зрители на Кръг Квадрат. Няма', start=13.48, duration=4.0), FetchedTranscriptSnippet(text='да съм водещ, слава', start=15.519, duration=3.561), FetchedTranscriptSnippet(text='богу.', start=17.48, duration=4.639), FetchedTranscriptSnippet(text='Радо Илиев, както винаги ще води, но аз', start=19.08, duration=4.8), FetchedTranscriptSnippet(text='искам да взимам думата в началото, за да', start=22.119, duration=4.281), FetchedTranscriptSnippet(text='представя двама мои стари приятели.', start=23.88, duration=4.639), FetchedTranscriptSnippet(text='Васил Велев.', start=26.4, duration=4.68), FetchedTranscriptSnippet(text='А трудно ми е да кажа какъв е в момента,', start=28.519, duration=4.801), FetchedTranscriptSnippet(text='защото той доскоро беше лидер на една', start=31.08, duration=3.6), FetchedTranscriptSnippet(text='много агресивна рабодателска'
# ...
